# %%
#Q1. Create a numpy array with 10 elements of the shape(10,1) using np.random and find out the mean of the elements using basic numpy functions.

import numpy as np
x=np.random.random((10,1))
print(x)
print("Mean = ",np.mean(x))
# Out:
# [[0.52715481]
#  [0.44741105]
#  [0.10958653]
#  [0.3850531 ]
#  [0.01443588]
#  [0.04881806]
#  [0.05513691]
#  [0.24441738]
#  [0.45550935]
#  [0.43810394]]
# Mean =  0.2725627008367349

# %%
#Q.2 - Create a numpy array with 20 elements of the shape(20,1) using np.random find the variance and standard deviation of the elements.

import numpy as np
x=np.random.random((20,1))
print(x)
print("Variance is ",np.var(x))
print("Standard deviationn is ",np.std(x))
# Out:
# [[0.70045287]
#  [0.52503636]
#  [0.79889   ]
#  [0.73137527]
#  [0.75036731]
#  [0.47346637]
#  [0.15121862]
#  [0.11818093]
#  [0.32408319]
#  [0.51607247]
#  [0.27449219]
#  [0.59135224]
#  [0.35130865]
#  [0.25941355]
#  [0.03901374]
#  [0.27819999]
#  [0.40886207]
#  [0.74936072]
#  [0.93143462]
#  [0.73524495]]
# Variance is  0.06271466064654721
# Standard deviationn is  0.25042895329124226

# %%
#Q.3 - Create a numpy array A of shape(10,20) and B of shape (20,25) using np.random. 
#      Print the matrix which is the matrix multiplication of A and B. The shape of the new matrix should be (10,25).
#      Using basic numpy math functions only find the sum of all the elements of the new matrix.

import numpy as np
A=np.random.random((10,20))
B=np.random.random((20,25))
C=np.matmul(A,B)
print(C)
print("Shape is ",C.shape)
print("Sum of all elements : ",np.sum(C))
# Out:
# [[4.37033107 4.63406365 3.31574127 5.05631052 4.12840391 3.96795151
#   3.56492903 3.4442461  4.5828631  4.03102697 3.97262701 5.0465925
#   4.71954301 2.46474901 4.3687352  3.21167343 4.71233503 3.29191432
#   3.64448228 4.62254293 4.85824596 3.29834103 3.10543957 4.56511557
#   4.72667687]
#  [4.9777214  4.86041389 3.88309792 5.00485454 4.42944615 4.03908754
#   4.86531494 4.39904234 5.00888459 4.83904925 4.64876963 4.94583089
#   5.55180677 3.51128969 4.70166574 3.87007905 5.83876391 3.99995334
#   4.56224315 4.34207605 4.7901433  4.20519659 3.02539161 5.18104406
#   5.00115495]
#  [3.66156732 3.50467009 3.67774273 4.58325625 3.94631727 4.3578711
#   5.20305065 4.61969664 3.9390799  3.74384543 3.6835258  4.38251354
#   4.60318357 3.31781352 4.38837733 3.35429775 4.20754779 3.09541163
#   4.51891319 4.00959411 4.40098437 3.16263664 3.38819797 4.9458298
#   3.57855919]
#  [5.07802524 5.41810695 4.23305848 5.93649703 5.10896433 5.5032159
#   5.49914579 5.21069661 5.64114602 5.45433887 4.55154191 5.9973427
#   5.66306534 4.13120195 5.31417981 4.49196653 6.10547255 4.0969091
#   5.03767348 6.0470923  6.06002939 4.63083692 5.19804804 6.22361607
#   5.92156651]
#  [5.57918393 6.12846812 4.85804306 6.81533027 5.55627789 5.03070616
#   6.00701777 5.75382518 6.02526477 5.30266109 5.35902839 6.04567074
#   5.77761268 3.76556392 4.9157413  4.4047647  6.11458518 4.39205003
#   5.55825259 5.73890932 5.68703378 4.04567306 4.87435939 6.40623175
#   5.58823548]
#  [5.72488267 5.22248908 4.39641361 6.23375273 5.44424607 4.98111801
#   5.93497125 5.52934703 5.68062987 5.51699504 5.32598049 5.9650705
#   5.92527047 4.13890161 6.03362024 4.64254485 6.29420308 4.24140348
#   5.03946614 5.57305313 6.25326363 4.42341245 4.34657664 6.46435297
#   5.98392777]
#  [3.97458439 4.74049362 4.38475755 6.10283087 5.13110602 4.62965539
#   4.64641094 5.01701882 5.3344601  4.50790185 5.13133239 4.82144217
#   4.04534384 3.2760759  4.94386746 4.23260512 5.3598586  4.24492735
#   4.35447072 5.8307296  5.50153473 3.48557269 3.93451476 5.80694058
#   4.67937932]
#  [4.45146421 5.09588023 4.83950718 6.07209215 5.00800673 4.98867426
#   5.47428563 4.83822242 5.39693257 4.41044753 4.69356946 5.46659254
#   5.52539397 3.95158223 5.20259116 4.4835502  5.93981828 4.25280431
#   5.40040405 5.85392363 6.15999158 4.23854532 4.25985859 6.59947595
#   5.39506605]
#  [5.56102384 5.96786522 5.45509672 6.75198513 5.95130673 5.80181401
#   5.51067995 5.54613688 5.97180492 5.04834501 5.47129761 6.34184333
#   5.36815813 3.77982145 5.51173081 4.63047238 6.17230766 4.05796962
#   5.42615688 6.48909321 6.72524266 4.3175012  5.47115562 6.28291018
#   6.30907678]
#  [6.16840593 6.53749421 5.63494012 7.01534551 5.80832621 5.26468331
#   6.61791851 6.02830248 6.02612243 5.46614832 5.87298492 6.49897735
#   6.78009051 4.26095286 5.71401324 4.74642712 6.8925006  4.7487293
#   6.25172502 5.7563639  6.33001156 4.73360051 5.00366068 6.88505867
#   6.25303389]]
# Shape is  (10, 25)
# Sum of all elements :  1253.3949150296316

# %%
#Q.4 - Create a numpy array A of shape(10,1).Using the basic operations of the numpy array generate an array of shape(10,1) such that each element is the following function applied on each element of A. 

import numpy as np

A=np.random.random((10,1))
print(A)

def fun(A):
    B=np.zeros((10,1))
    for i in range(10):
        x=1 / (1 + np.exp(-A[i]))
        B[i]=x
    print(B)
print("- "*20)
fun(A)
# Out:
# [[0.81316517]
#  [0.14087069]
#  [0.54830041]
#  [0.55302147]
#  [0.29707489]
#  [0.67327008]
#  [0.69069252]
#  [0.6936543 ]
#  [0.515974  ]
#  [0.39525535]]
# - - - - - - - - - - - - - - - - - - - -
# [[0.69278357]
#  [0.53515955]
#  [0.63374118]
#  [0.63483631]
#  [0.57372729]
#  [0.662235  ]
#  [0.66612096]
#  [0.66677935]
#  [0.62620587]
#  [0.59754718]]
